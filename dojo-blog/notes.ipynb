# %% [markdown]
# ![image.png](attachment:image.png)
#
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# lec 3-
# ![image.png](attachment:image.png)
#
# # bable converts the jsc in html -- this code inside function is jsx-
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# lec 5-
# ![image.png](attachment:image.png)
